# %%
import pandas as pd

Kilimani = pd.read_csv('Rent_kILIMANI_Data.csv')

# %%
Kilimani
# Out:
#                                                  Title  Bedrooms  Bathrooms  \
# 0    Serviced 1 Bed Apartment with En Suite in Kili...         1          2
# 1       3 Bed Apartment with Swimming Pool in Kilimani         3          3
# 2    Serviced 3 Bed Apartment with En Suite at Walk...         3          2
# 3    Furnished 3 Bed Apartment with Swimming Pool i...         3          2
# 4    Furnished 1 Bed Apartment with En Suite at Kil...         1          2
# ..                                                 ...       ...        ...
# 115          2 Bed Apartment with En Suite in Kilimani         2          3
# 116  Serviced 1 Bed Apartment with En Suite in Kili...         1          2
# 117  Furnished 1 Bed Apartment with En Suite in Kil...         1          1
# 118          2 Bed Apartment with En Suite in Kilimani         2          2
# 119      Serviced 1 Bed Apartment with Gym in Kilimani         1          1
#
#           Prices
# 0    KSh 130,000
# 1    KSh 105,000
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression

# %%
price = Kilimani["Prices"]
mypricelist = list(price )

mypricelist


cleaned_prices = [int(price.replace('KSh ', '').replace(',', '')) if 'KSh' in price else None for price in mypricelist]
prices = []
for price in cleaned_prices:
    prices.append(price)


prices

title = Kilimani["Title"]
mytitlelist = list(title)

bedrooms = Kilimani["Bedrooms"]
mybedroomslist = list(bedrooms)

Bathrooms = Kilimani["Bathrooms"]
mybathroomslist = list(Bathrooms)

import pandas as pd
KilimaniDataframe = pd.DataFrame({"Title" : mytitlelist,"Bedrooms" : mybedroomslist,"Bathrooms" : mybathroomslist , "Prices" :prices })

KilimaniDataframe

import pandas as pd

KilimaniDataframe = pd.DataFrame({
    "Title": mytitlelist,
    "Bedrooms": mybedroomslist,
    "Bathrooms": mybathroomslist,
    "Prices": prices
})

# %%
indices_to_remove = [18, 98]


KilimaniDataframe = KilimaniDataframe.drop(indices_to_remove)


KilimaniDataframe = KilimaniDataframe.reset_index(drop=True)


KilimaniDataframe
# Out:
#                                                  Title  Bedrooms  Bathrooms  \
# 0    Serviced 1 Bed Apartment with En Suite in Kili...         1          2
# 1       3 Bed Apartment with Swimming Pool in Kilimani         3          3
# 2    Serviced 3 Bed Apartment with En Suite at Walk...         3          2
# 3    Furnished 3 Bed Apartment with Swimming Pool i...         3          2
# 4    Furnished 1 Bed Apartment with En Suite at Kil...         1          2
# ..                                                 ...       ...        ...
# 113          2 Bed Apartment with En Suite in Kilimani         2          3
# 114  Serviced 1 Bed Apartment with En Suite in Kili...         1          2
# 115  Furnished 1 Bed Apartment with En Suite in Kil...         1          1
# 116          2 Bed Apartment with En Suite in Kilimani         2          2
# 117      Serviced 1 Bed Apartment with Gym in Kilimani         1          1
#
#        Prices
# 0    130000.0
# 1    105000.0
# ...

# %%
features = ['Bedrooms','Bathrooms']
target = 'Prices'


KilimaniDataframe = KilimaniDataframe.dropna(subset=[target])


x = KilimaniDataframe[features]
y = KilimaniDataframe[target]


model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
new_data_kilimani = pd.DataFrame([[2,1]], columns = features)

new_data_kilimani

predicted_price_kilimani = model.predict(new_data_kilimani)

print("Predicted Price kilimani" ,predicted_price_kilimani)
# Out:
# Predicted Price kilimani [113922.47237816]

# %%
Ruaka = pd.read_csv('Rent_RUAKA_Data.csv')

# %%
Ruaka
# Out:
#                                                 Title  Bedrooms  Bathrooms  \
# 0               2 Bed Apartment with Parking in Ruaka         2          0
# 1                  1 Bed Apartment with Lift in Ruaka         1          2
# 2   Serviced Studio Apartment with En Suite at Rua...         1          1
# 3              2 Bed Apartment with En Suite in Ruaka         2          2
# 4              2 Bed Apartment with En Suite in Ruaka         2          3
# 5   2 Bed Apartment with En Suite at Limuru Road -...         2          2
# 6              2 Bed Apartment with En Suite in Ruaka         2          0
# 7      Serviced 1 Bed Apartment with Parking in Ruaka         1          1
# 8              2 Bed Apartment with En Suite in Ruaka         2          3
# 9                            3 Bed Apartment in Ruaka         3          2
# 10             2 Bed Apartment with En Suite in Ruaka         2          2
# ...

# %%
price =Ruaka["Prices"]
mypricelist = list(price )

cleaned_prices = [int(price.replace('KSh ', '').replace(',', '')) if 'KSh' in price else None for price in mypricelist]
prices = []
for price in cleaned_prices:
    prices.append(price)


prices

import pandas as pd


title = Ruaka["Title"]
mytitlelist = list(title)

bedrooms = Ruaka["Bedrooms"]
mybedroomslist = list(bedrooms)

Bathrooms = Ruaka["Bathrooms"]
mybathroomslist = list(Bathrooms)

import pandas as pd
RuakaDataframe = pd.DataFrame({"Title" : mytitlelist,"Bedrooms" : mybedroomslist,"Bathrooms" : mybathroomslist , "Prices" :prices })

# %%
RuakaDataframe
# Out:
#                                                 Title  Bedrooms  Bathrooms  \
# 0               2 Bed Apartment with Parking in Ruaka         2          0
# 1                  1 Bed Apartment with Lift in Ruaka         1          2
# 2   Serviced Studio Apartment with En Suite at Rua...         1          1
# 3              2 Bed Apartment with En Suite in Ruaka         2          2
# 4              2 Bed Apartment with En Suite in Ruaka         2          3
# 5   2 Bed Apartment with En Suite at Limuru Road -...         2          2
# 6              2 Bed Apartment with En Suite in Ruaka         2          0
# 7      Serviced 1 Bed Apartment with Parking in Ruaka         1          1
# 8              2 Bed Apartment with En Suite in Ruaka         2          3
# 9                            3 Bed Apartment in Ruaka         3          2
# 10             2 Bed Apartment with En Suite in Ruaka         2          2
# ...

# %%
features = ['Bedrooms','Bathrooms']
target = 'Prices'

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression



RuakaDataframe = RuakaDataframe.dropna(subset=[target])


x = RuakaDataframe[features]
y = RuakaDataframe[target]


model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
new_data_Ruaka = pd.DataFrame([[2,1]], columns = features)

new_data_Ruaka

predicted_price_Ruaka = model.predict(new_data_Ruaka)

print("Predicted Price Ruaka" ,predicted_price_Ruaka)
# Out:
# Predicted Price Ruaka [42413.75821952]

# %%
import pandas as pd

# Read the CSV file
Kileleshwa = pd.read_csv('Rent_kILELESHWA_Data.csv')

# Extract data from the Kileleshwa DataFrame
price = Kileleshwa["Prices"]
mypricelist = list(price)

# Clean the prices data
cleaned_prices = [int(price.replace('KSh ', '').replace(',', '')) if 'KSh' in price else None for price in mypricelist]
prices = [price for price in cleaned_prices]

title = Kileleshwa["Title"]
mytitlelist = list(title)

bedrooms = Kileleshwa["Bedrooms"]
mybedroomslist = list(bedrooms)

bathrooms = Kileleshwa["Bathrooms"]
mybathroomslist = list(bathrooms)

# Create a DataFrame for Kileleshwa
KileleshwaDataframe = pd.DataFrame({
    "Title": mytitlelist,
    "Bedrooms": mybedroomslist,
    "Bathrooms": mybathroomslist,
    "Prices": prices
})

# Create a DataFrame for Kilimani (assuming it's a separate DataFrame)
KilimaniDataframe = pd.DataFrame({
    "Title": mytitlelist,
    "Bedrooms": mybedroomslist,
    "Bathrooms": mybathroomslist,
    "Prices": prices
})

# Find indices where 'Bedrooms' is not found for this link
indices_to_remove = KilimaniDataframe[KilimaniDataframe['Bedrooms'] == 'Title not found for this link'].index

# Drop rows with the specified indices
KileleshwaDataframe = KilimaniDataframe.drop(indices_to_remove)

# Reset the index of the DataFrame
KileleshwaDataframe = KileleshwaDataframe.reset_index(drop=True)

# Display the resulting DataFrame
KileleshwaDataframe
# Out:
#                                                  Title Bedrooms  Bathrooms  \
# 0          3 Bed Apartment with En Suite at Kileleshwa        3          3
# 1          3 Bed Apartment with En Suite in Kileleshwa        3          2
# 2    Serviced 2 Bed Apartment with En Suite in Kile...        2          3
# 3           Furnished 2 Bed Apartment with En Suite at        2          2
# 4    Furnished 2 Bed Apartment with En Suite in Kil...        2          2
# ..                                                 ...      ...        ...
# 108         2 Bed Apartment with Parking at Githunguri        2          1
# 109  Furnished 1 Bed Apartment with En Suite in Kil...        1          1
# 110        2 Bed Apartment with En Suite at Kileleshwa        2          2
# 111        3 Bed Apartment with En Suite at Kileleshwa        3          3
# 112  Serviced 1 Bed Apartment with En Suite at Kile...        1          1
#
#        Prices
# 0     85000.0
# 1     85000.0
# 2    200000.0
# ...

# %%
import pandas as pd
df = pd.DataFrame(KileleshwaDataframe )

df.to_csv('NEED TO CHECK.csv', index=False)

# %%
from sklearn.impute import SimpleImputer

# %%
features = ['Bedrooms','Bathrooms']
target = 'Prices'



KileleshwaDataframe = KileleshwaDataframe.dropna(subset=[target])

x = KileleshwaDataframe[features]
y = KileleshwaDataframe[target]



model = LinearRegression()

model

model.fit(x, y)
# Out:
# LinearRegression()

# %%
new_data_kileleshwa = pd.DataFrame([[2,1]], columns = features)

new_data_kileleshwa
# Out:
#    Bedrooms  Bathrooms
# 0         2          1

# %%
predicted_price_kileleshwa = model.predict(new_data_kileleshwa)

print("Predicted Price kileleshwa" ,predicted_price_kileleshwa)
# Out:
# Predicted Price kileleshwa [113632.17889954]

# %%
Westlands = pd.read_csv('Rent_WESTLANDS_Data.csv')

Westlands
# Out:
#                                                  Title  Bedrooms  Bathrooms  \
# 0           3 Bed Apartment with En Suite at Peponi Rd         3          3
# 1    Furnished 1 Bed Apartment with Swimming Pool a...         1          1
# 2           2 Bed Apartment with En Suite in Brookside         2          3
# 3    Furnished 2 Bed Apartment with En Suite in Wes...         2          2
# 4           4 Bed Apartment with En Suite in Riverside         4          3
# ..                                                 ...       ...        ...
# 121         3 Bed Apartment with En Suite in Riverside         3          3
# 122        2 Bed Apartment with Parking in Waiyaki Way         2          2
# 123  Serviced 2 Bed Apartment with En Suite at Spri...         2          2
# 124          Serviced 2 Bed Apartment with En Suite at         2          2
# 125  Serviced 2 Bed Apartment with En Suite in West...         2          2
#
#           Prices
# 0    KSh 350,000
# 1    KSh 170,000
# ...

# %%
price =Westlands["Prices"]
mypricelist = list(price )

cleaned_prices = [int(price.replace('KSh ', '').replace(',', '')) if 'KSh' in price else None for price in mypricelist]
prices = []
for price in cleaned_prices:
    prices.append(price)


prices
# Out:
# [350000,
#  170000,
#  95000,
#  260000,
#  170000,
#  200000,
#  140000,
#  180000,
#  300000,
#  182000,
#  90000,
#  260000,
#  230000,
#  150000,
#  160000,
#  330000,
#  200000,
#  420000,
#  350000,
#  160000,
#  75000,
#  220000,
#  160000,
#  250000,
#  120000,
#  260000,
#  180000,
#  250000,
#  65000,
#  150000,
#  160000,
#  150000,
#  150000,
#  230000,
#  200000,
#  340000,
#  200000,
#  270000,
#  200000,
#  220000,
#  140000,
#  150000,
#  220000,
#  120000,
#  150000,
#  150000,
#  302000,
#  250000,
#  300000,
#  150000,
#  170000,
#  75000,
#  350000,
#  295000,
#  380000,
#  180000,
#  450000,
#  350000,
#  140000,
#  120000,
#  450000,
#  240000,
#  430000,
#  590000,
#  100000,
#  150000,
#  250000,
#  370000,
#  55000,
#  280000,
#  650000,
#  170000,
#  200000,
#  300000,
#  280000,
#  280000,
#  120000,
#  110000,
#  350000,
#  170000,
#  110000,
#  350000,
#  160000,
#  145000,
#  165000,
#  297000,
#  100000,
#  180000,
#  150000,
#  65000,
#  120000,
# ...

# %%
import pandas as pd


title = Westlands["Title"]
mytitlelist = list(title)

bedrooms = Westlands["Bedrooms"]
mybedroomslist = list(bedrooms)

Bathrooms = Westlands["Bathrooms"]
mybathroomslist = list(Bathrooms)

import pandas as pd
WestlandsDataframe = pd.DataFrame({"Title" : mytitlelist,"Bedrooms" : mybedroomslist,"Bathrooms" : mybathroomslist , "Prices" :prices })



WestlandsDataframe
# Out:
#                                                  Title  Bedrooms  Bathrooms  \
# 0           3 Bed Apartment with En Suite at Peponi Rd         3          3
# 1    Furnished 1 Bed Apartment with Swimming Pool a...         1          1
# 2           2 Bed Apartment with En Suite in Brookside         2          3
# 3    Furnished 2 Bed Apartment with En Suite in Wes...         2          2
# 4           4 Bed Apartment with En Suite in Riverside         4          3
# ..                                                 ...       ...        ...
# 121         3 Bed Apartment with En Suite in Riverside         3          3
# 122        2 Bed Apartment with Parking in Waiyaki Way         2          2
# 123  Serviced 2 Bed Apartment with En Suite at Spri...         2          2
# 124          Serviced 2 Bed Apartment with En Suite at         2          2
# 125  Serviced 2 Bed Apartment with En Suite in West...         2          2
#
#        Prices
# 0    350000.0
# 1    170000.0
# ...

# %%
import pandas as pd

KilimaniDataframe = pd.DataFrame({
    "Title": mytitlelist,
    "Bedrooms": mybedroomslist,
    "Bathrooms": mybathroomslist,
    "Prices": prices
})

indices_to_remove = [103]


WestlandsDataframe = WestlandsDataframe.drop(indices_to_remove)


WestlandsDataframe = KilimaniDataframe.reset_index(drop=True)


WestlandsDataframe


features = ['Bedrooms','Bathrooms']
target = 'Prices'

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression



WestlandsDataframe = WestlandsDataframe.dropna(subset=[target])


x = WestlandsDataframe[features]
y = WestlandsDataframe[target]


model = LinearRegression()
model.fit(x, y)


new_data_Weslands = pd.DataFrame([[2,1]], columns = features)

# %%
new_data_Weslands
# Out:
#    Bedrooms  Bathrooms
# 0         2          1

# %%
# Predict the price for the Westlands location using the model
predicted_price_Westlands = model.predict(new_data_Westlands)

# Print the predicted price for Westlands
print("Predicted Price Westlands:", predicted_price_Westlands)
# Out:
# Predicted Price Westlands [153115.00006104]

# %%
# Print the predicted prices for each location
print("Predicted Price Kilimani:", predicted_price_kilimani)
print("Predicted Price Ruaka:", predicted_price_Ruaka)
print("Predicted Price Kileleshwa:", predicted_price_Kileleshwa)
print("Predicted Price Westlands:", predicted_price_Westlands)
# Out:
# Predicted Price kilimani [113922.47237816]
# Predicted Price Ruaka [42413.75821952]
# Predicted Price kileleshwa [113632.17889954]
# Predicted Price Westlands [153115.00006104]

# %%
# Importing the necessary library
import matplotlib.pyplot as plt

# Data for locations and predicted prices
locations = ['Kilimani', 'Ruaka', 'Kileleshwa', 'Westlands']
predicted_prices = [113922.47, 42413.76, 113632.18, 153115.00]

# Colors for the bars corresponding to each location
colors = ['red', 'blue', 'green', 'darkblue']

# Creating a bar plot
plt.bar(locations, predicted_prices, color=colors)

# Adding labels to the x and y axes
plt.xlabel('Locations')
plt.ylabel('Predicted Prices')

# Adding a title to the plot
plt.title('Predicted Prices for Different Locations')

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

locations = ['Kilimani', 'Ruaka', 'Kileleshwa', 'Westlands']
predicted_prices = [113922.47, 42413.76, 113632.18, 153115.00]


line_color = 'blue'

plt.plot(locations, predicted_prices, marker='o', color=line_color, linewidth=2, markersize=8)
plt.xlabel('Locations')
plt.ylabel('Predicted Prices')
plt.title('Predicted Prices for Different Locations (Line Plot)')
plt.grid(False)
plt.show()
