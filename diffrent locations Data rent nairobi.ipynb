# %%
import pandas as pd

# %%
Kilimani = pd.read_csv('Rent_kILIMANI_Data.csv')

# %%
Kilimani
# Out:
#                                                  Title  Bedrooms  Bathrooms  \
# 0    Serviced 1 Bed Apartment with En Suite in Kili...         1          2
# 1       3 Bed Apartment with Swimming Pool in Kilimani         3          3
# 2    Serviced 3 Bed Apartment with En Suite at Walk...         3          2
# 3    Furnished 3 Bed Apartment with Swimming Pool i...         3          2
# 4    Furnished 1 Bed Apartment with En Suite at Kil...         1          2
# ..                                                 ...       ...        ...
# 115          2 Bed Apartment with En Suite in Kilimani         2          3
# 116  Serviced 1 Bed Apartment with En Suite in Kili...         1          2
# 117  Furnished 1 Bed Apartment with En Suite in Kil...         1          1
# 118          2 Bed Apartment with En Suite in Kilimani         2          2
# 119      Serviced 1 Bed Apartment with Gym in Kilimani         1          1
#
#           Prices
# 0    KSh 130,000
# 1    KSh 105,000
# ...

# %%
Kileleshwa = pd.read_csv('Rent_kILELESHWA_Data.csv')

# %%
Kileleshwa
# Out:
#                                                  Title Bedrooms  Bathrooms  \
# 0          3 Bed Apartment with En Suite at Kileleshwa        3          3
# 1          3 Bed Apartment with En Suite in Kileleshwa        3          2
# 2    Serviced 2 Bed Apartment with En Suite in Kile...        2          3
# 3           Furnished 2 Bed Apartment with En Suite at        2          2
# 4    Furnished 2 Bed Apartment with En Suite in Kil...        2          2
# ..                                                 ...      ...        ...
# 115         2 Bed Apartment with Parking at Githunguri        2          1
# 116  Furnished 1 Bed Apartment with En Suite in Kil...        1          1
# 117        2 Bed Apartment with En Suite at Kileleshwa        2          2
# 118        3 Bed Apartment with En Suite at Kileleshwa        3          3
# 119  Serviced 1 Bed Apartment with En Suite at Kile...        1          1
#
#           Prices
# 0     KSh 85,000
# 1     KSh 85,000
# ...

# %%
Ruaka = pd.read_csv('Rent_RUAKA_Data.csv')

# %%
Ruaka
# Out:
#                                                 Title  Bedrooms  Bathrooms  \
# 0               2 Bed Apartment with Parking in Ruaka         2          0
# 1                  1 Bed Apartment with Lift in Ruaka         1          2
# 2   Serviced Studio Apartment with En Suite at Rua...         1          1
# 3              2 Bed Apartment with En Suite in Ruaka         2          2
# 4              2 Bed Apartment with En Suite in Ruaka         2          3
# 5   2 Bed Apartment with En Suite at Limuru Road -...         2          2
# 6              2 Bed Apartment with En Suite in Ruaka         2          0
# 7      Serviced 1 Bed Apartment with Parking in Ruaka         1          1
# 8              2 Bed Apartment with En Suite in Ruaka         2          3
# 9                            3 Bed Apartment in Ruaka         3          2
# 10             2 Bed Apartment with En Suite in Ruaka         2          2
# ...

# %%
Westlands = pd.read_csv('Rent_WESTLANDS_Data.csv')

# %%
Westlands
# Out:
#                                                  Title  Bedrooms  Bathrooms  \
# 0           3 Bed Apartment with En Suite at Peponi Rd         3          3
# 1    Furnished 1 Bed Apartment with Swimming Pool a...         1          1
# 2           2 Bed Apartment with En Suite in Brookside         2          3
# 3    Furnished 2 Bed Apartment with En Suite in Wes...         2          2
# 4           4 Bed Apartment with En Suite in Riverside         4          3
# ..                                                 ...       ...        ...
# 121         3 Bed Apartment with En Suite in Riverside         3          3
# 122        2 Bed Apartment with Parking in Waiyaki Way         2          2
# 123  Serviced 2 Bed Apartment with En Suite at Spri...         2          2
# 124          Serviced 2 Bed Apartment with En Suite at         2          2
# 125  Serviced 2 Bed Apartment with En Suite in West...         2          2
#
#           Prices
# 0    KSh 350,000
# 1    KSh 170,000
# ...
